# %%
## Importing important libraries:

import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn import preprocessing


from sklearn import metrics
from sklearn.metrics import accuracy_score as acc


from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict


from sklearn.metrics import make_scorer, accuracy_score
from sklearn.model_selection import GridSearchCV,RandomizedSearchCV

# %%
#Reading the data:

data=pd.read_csv('data.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  match_event_id  location_x  location_y  remaining_min  \
# 0           0            10.0       167.0        72.0           10.0
# 1           1            12.0      -157.0         0.0           10.0
# 2           2            35.0      -101.0       135.0            7.0
# 3           3            43.0       138.0       175.0            6.0
# 4           4           155.0         0.0         0.0            NaN
#
#    power_of_shot  knockout_match game_season  remaining_sec  distance_of_shot  \
# 0            1.0             0.0     2000-01           27.0              38.0
# 1            1.0             0.0     2000-01           22.0              35.0
# 2            1.0             0.0     2000-01           45.0              36.0
# 3            1.0             0.0     2000-01           52.0              42.0
# 4            2.0             0.0     2000-01           19.0              20.0
#
#    ...                 lat/lng type_of_shot type_of_combined_shot  match_id  \
# ...

# %%
data.describe()
# Out:
#          Unnamed: 0  match_event_id    location_x    location_y  \
# count  30697.000000    29134.000000  29236.000000  29157.000000
# mean   15348.000000      249.576028      7.383876     91.126933
# std     8861.604943      150.186019    110.263049     87.676395
# min        0.000000        2.000000   -250.000000    -44.000000
# 25%     7674.000000      111.000000    -68.000000      4.000000
# 50%    15348.000000      254.000000      0.000000     74.000000
# 75%    23022.000000      369.000000     95.000000    160.000000
# max    30696.000000      659.000000    248.000000    791.000000
#
#        remaining_min  power_of_shot  knockout_match  remaining_sec  \
# count   29135.000000   29211.000000    29180.000000   29103.000000
# mean        4.883233       2.519359        0.145956      28.329382
# std         3.452533       1.153976        0.353068      17.470663
# min         0.000000       1.000000        0.000000       0.000000
# ...

# %%
data.shape
# Out:
# (30697, 28)

# %%
## Dropping unnecessary columns from the dataset:

data.drop(columns=['Unnamed: 0','match_event_id','game_season','team_name','date_of_game','shot_id_number','lat/lng','type_of_shot','type_of_combined_shot','match_id','team_id',],inplace=True)
data=data.iloc[:,:-5]

# %%
data.head()
# Out:
#    location_x  location_y  remaining_min  power_of_shot  knockout_match  \
# 0       167.0        72.0           10.0            1.0             0.0
# 1      -157.0         0.0           10.0            1.0             0.0
# 2      -101.0       135.0            7.0            1.0             0.0
# 3       138.0       175.0            6.0            1.0             0.0
# 4         0.0         0.0            NaN            2.0             0.0
#
#    remaining_sec  distance_of_shot  is_goal           area_of_shot  \
# 0           27.0              38.0      NaN          Right Side(R)
# 1           22.0              35.0      0.0           Left Side(L)
# 2           45.0              36.0      1.0   Left Side Center(LC)
# 3           52.0              42.0      0.0  Right Side Center(RC)
# 4           19.0              20.0      1.0              Center(C)
#
#   shot_basics    range_of_shot   home/away
# 0   Mid Range        16-24 ft.  MANU @ POR
# ...

# %%
data.shape
# Out:
# (30697, 12)

# %%
data.describe()
# Out:
#          location_x    location_y  remaining_min  power_of_shot  \
# count  29236.000000  29157.000000   29135.000000   29211.000000
# mean       7.383876     91.126933       4.883233       2.519359
# std      110.263049     87.676395       3.452533       1.153976
# min     -250.000000    -44.000000       0.000000       1.000000
# 25%      -68.000000      4.000000       2.000000       1.000000
# 50%        0.000000     74.000000       5.000000       3.000000
# 75%       95.000000    160.000000       8.000000       3.000000
# max      248.000000    791.000000      11.000000       7.000000
#
#        knockout_match  remaining_sec  distance_of_shot       is_goal
# count    29180.000000   29103.000000      29130.000000  24429.000000
# mean         0.145956      28.329382         33.448884      0.445331
# std          0.353068      17.470663          9.369656      0.497013
# min          0.000000       0.000000         20.000000      0.000000
# ...

# %%
data.describe(include='all')
# Out:
#           location_x    location_y  remaining_min  power_of_shot  \
# count   29236.000000  29157.000000   29135.000000   29211.000000
# unique           NaN           NaN            NaN            NaN
# top              NaN           NaN            NaN            NaN
# freq             NaN           NaN            NaN            NaN
# mean        7.383876     91.126933       4.883233       2.519359
# std       110.263049     87.676395       3.452533       1.153976
# min      -250.000000    -44.000000       0.000000       1.000000
# 25%       -68.000000      4.000000       2.000000       1.000000
# 50%         0.000000     74.000000       5.000000       3.000000
# 75%        95.000000    160.000000       8.000000       3.000000
# max       248.000000    791.000000      11.000000       7.000000
#
#         knockout_match  remaining_sec  distance_of_shot       is_goal  \
# count     29180.000000   29103.000000      29130.000000  24429.000000
# ...

# %%
data['shot_basics'].value_counts()
# Out:
# Mid Range          11955
# Goal Area           6787
# Penalty Spot        5321
# Goal Line           4357
# Right Corner         367
# Left Corner          268
# Mid Ground Line       67
# Name: shot_basics, dtype: int64

# %%
data['range_of_shot'].value_counts()
# Out:
# Less Than 8 ft.    8933
# 16-24 ft.          7892
# 8-16 ft.           6290
# 24+ ft.            5937
# Back Court Shot      81
# Name: range_of_shot, dtype: int64

# %%
data['area_of_shot'].value_counts()
# Out:
# Center(C)                12761
# Right Side Center(RC)     4562
# Right Side(R)             4370
# Left Side Center(LC)      3848
# Left Side(L)              3573
# Mid Ground(MG)              81
# Name: area_of_shot, dtype: int64

# %%
data.isnull().sum()
# Out:
# location_x          1461
# location_y          1540
# remaining_min       1562
# power_of_shot       1486
# knockout_match      1517
# remaining_sec       1594
# distance_of_shot    1567
# is_goal             6268
# area_of_shot        1502
# shot_basics         1575
# range_of_shot       1564
# home/away           1497
# dtype: int64

# %%
data.describe()
# Out:
#          location_x    location_y  remaining_min  power_of_shot  \
# count  29236.000000  29157.000000   29135.000000   29211.000000
# mean       7.383876     91.126933       4.883233       2.519359
# std      110.263049     87.676395       3.452533       1.153976
# min     -250.000000    -44.000000       0.000000       1.000000
# 25%      -68.000000      4.000000       2.000000       1.000000
# 50%        0.000000     74.000000       5.000000       3.000000
# 75%       95.000000    160.000000       8.000000       3.000000
# max      248.000000    791.000000      11.000000       7.000000
#
#        knockout_match  remaining_sec  distance_of_shot       is_goal
# count    29180.000000   29103.000000      29130.000000  24429.000000
# mean         0.145956      28.329382         33.448884      0.445331
# std          0.353068      17.470663          9.369656      0.497013
# min          0.000000       0.000000         20.000000      0.000000
# ...

# %%
## Filling the reamining missing values:

data['location_x'].fillna(data['location_x'].mean(), inplace=True)
data['location_y'].fillna(data['location_y'].mean(), inplace=True)
data['remaining_min'].fillna(data['remaining_min'].mean(), inplace=True)
data['power_of_shot'].fillna(data['power_of_shot'].median(), inplace=True)
data['knockout_match'].fillna(data['knockout_match'].median(), inplace=True)
data['remaining_sec'].fillna(data['remaining_sec'].mean(), inplace=True)
data['distance_of_shot'].fillna(data['distance_of_shot'].mean(), inplace=True)
data['shot_basics'].fillna(value='Mid Range', inplace=True)
data['range_of_shot'].fillna(value='Less Than 8 ft.', inplace=True)
data['area_of_shot'].fillna(value='Center(C)', inplace=True)
data['home/away'].fillna(value='MANU @ SAS', inplace=True)

# %%
data.isnull().sum()
# Out:
# location_x             0
# location_y             0
# remaining_min          0
# power_of_shot          0
# knockout_match         0
# remaining_sec          0
# distance_of_shot       0
# is_goal             6268
# area_of_shot           0
# shot_basics            0
# range_of_shot          0
# home/away              0
# dtype: int64

# %%
## Transforming the feature 'home/away' into a categorical variable having values only 'home' and 'away' :

for i in range(data.shape[0]):
    if('@' in data.loc[i,'home/away']):
        data.loc[i,'home/away']='away'
        
    if('vs' in data.loc[i,'home/away']):
        data.loc[i,'home/away']='home'

# %%
data.head()
# Out:
#    location_x  location_y  remaining_min  power_of_shot  knockout_match  \
# 0       167.0        72.0      10.000000            1.0             0.0
# 1      -157.0         0.0      10.000000            1.0             0.0
# 2      -101.0       135.0       7.000000            1.0             0.0
# 3       138.0       175.0       6.000000            1.0             0.0
# 4         0.0         0.0       4.883233            2.0             0.0
#
#    remaining_sec  distance_of_shot  is_goal           area_of_shot  \
# 0           27.0              38.0      NaN          Right Side(R)
# 1           22.0              35.0      0.0           Left Side(L)
# 2           45.0              36.0      1.0   Left Side Center(LC)
# 3           52.0              42.0      0.0  Right Side Center(RC)
# 4           19.0              20.0      1.0              Center(C)
#
#   shot_basics    range_of_shot home/away
# 0   Mid Range        16-24 ft.      away
# 1   Mid Range         8-16 ft.      away
# ...

# %%
## Splitting the data into train and test dataset:

test=data[data['is_goal'].isnull()]
train=data[data['is_goal'].notnull()]

# %%
data.dtypes
# Out:
# location_x          float64
# location_y          float64
# remaining_min       float64
# power_of_shot       float64
# knockout_match      float64
# remaining_sec       float64
# distance_of_shot    float64
# is_goal             float64
# area_of_shot         object
# shot_basics          object
# range_of_shot        object
# home/away            object
# dtype: object

# %%
data.columns
# Out:
# Index(['location_x', 'location_y', 'remaining_min', 'power_of_shot',
#        'knockout_match', 'remaining_sec', 'distance_of_shot', 'is_goal',
#        'area_of_shot', 'shot_basics', 'range_of_shot', 'home/away'],
#       dtype='object')

# %%
### PREPARING y, X AND X_test:

y=train['is_goal'].values

X=train[['location_x', 'location_y', 'remaining_min', 'power_of_shot','knockout_match', 'remaining_sec', 'distance_of_shot','area_of_shot', 'shot_basics', 'range_of_shot', 'home/away']].values
X_test=test[['location_x', 'location_y', 'remaining_min', 'power_of_shot','knockout_match', 'remaining_sec', 'distance_of_shot','area_of_shot', 'shot_basics', 'range_of_shot', 'home/away']].values

# %%
### LABEL ENCODING:

area_of_shot=preprocessing.LabelEncoder()
shot_basics=preprocessing.LabelEncoder()
range_of_shot=preprocessing.LabelEncoder()
last=preprocessing.LabelEncoder()

## FOR Area_of_shot:

area_of_shot.fit(['Mid Ground(MG)','Right Side(R)', 'Left Side(L)', 'Left Side Center(LC)','Right Side Center(RC)', 'Center(C)'])

X[:,-4]=area_of_shot.transform(X[:,-4])
X_test[:,-4]=area_of_shot.transform(X_test[:,-4])


## FOR Shot_basics:

shot_basics.fit(['Mid Range','Mid Ground Line', 'Right Corner', 'Left Corner' ,'Goal Area', 'Goal Line', 'Penalty Spot'])

X[:,-3]=shot_basics.transform(X[:,-3])
X_test[:,-3]=shot_basics.transform(X_test[:,-3])


## FOR Range_of_shot:

range_of_shot.fit(['Back Court Shot','24+ ft.','16-24 ft.', '8-16 ft.', 'Less Than 8 ft.'])

X[:,-2]=range_of_shot.transform(X[:,-2])
X_test[:,-2]=range_of_shot.transform(X_test[:,-2])

## FOR last column:

last.fit(['away','home'])

X[:,-1]=last.transform(X[:,-1])
X_test[:,-1]=last.transform(X_test[:,-1])

# %%
### STANDARDISING X AND X_TEST:


X_=preprocessing.StandardScaler().fit(X).transform(X)
X_test_=preprocessing.StandardScaler().fit(X_test).transform(X_test)

# %%
### TEST TRAIN SPLIT:

x_train,x_test_,Y_train,Y_test=train_test_split(X_,y,test_size=0.3,random_state=0)

# %%
### LOGISTIC REGRESSION:

from sklearn.linear_model import LogisticRegression

lr=LogisticRegression(C=5, solver='liblinear').fit(x_train,Y_train)

yhat=lr.predict(x_test_)

acc(Y_test,yhat)*100
# Out:
# 59.216809933142315

# %%
# KNN:

from sklearn.neighbors import KNeighborsClassifier

k=1000


neigh=KNeighborsClassifier(n_neighbors=k).fit(x_train,Y_train)

yhat1=neigh.predict(x_test_)

acc(Y_test,yhat1)*100
# Out:
# 59.46240960567608

# %%
### SVM (RBF)

from sklearn import svm

clf3=svm.SVC(kernel='rbf',gamma=0.05, C=8, probability=True)


clf3.fit(x_train,Y_train)

yhat3=clf3.predict(x_test_)

(acc(Y_test,yhat3))*100
# Out:
# 59.91267567198799

# %%
### DECISION TREE:

from sklearn.tree import DecisionTreeClassifier

tree=DecisionTreeClassifier(criterion='entropy', max_depth=4)



tree.fit(x_train,Y_train)

yhat2=tree.predict(x_test_)

acc(Y_test,yhat2)*100
# Out:
# 59.9672533769955

# %%
### RANDOM FOREST CLASSIFIER

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import make_scorer, accuracy_score
from sklearn.model_selection import GridSearchCV

# Choose the type of classifier. 
rnd = RandomForestClassifier()


### TO GET PARAMETERS OF ANY MODEL:

rnd.get_params().keys()
# Out:
# dict_keys(['bootstrap', 'class_weight', 'criterion', 'max_depth', 'max_features', 'max_leaf_nodes', 'min_impurity_decrease', 'min_impurity_split', 'min_samples_leaf', 'min_samples_split', 'min_weight_fraction_leaf', 'n_estimators', 'n_jobs', 'oob_score', 'random_state', 'verbose', 'warm_start'])

# %%
### GRIDSEARCH + RANDOM FOREST CLASSIFIER:


# Choose some parameter combinations to try
parameters = {'n_estimators': [4, 6, 9], 
              'max_features': ['log2', 'sqrt','auto'], 
              'criterion': ['entropy', 'gini'],
              'max_depth': [2, 3,5, 6, 10], 
              'min_samples_split': [2, 3, 5],
              'min_samples_leaf': [1,5,8]
             }

# Type of scoring used to compare parameter combinations
acc_scorer = make_scorer(accuracy_score)

# Run the grid search
grid_obj = GridSearchCV(rnd, parameters, scoring=acc_scorer)
grid_obj = grid_obj.fit(x_train, Y_train)

# Set the clf to the best combination of parameters
rnd = grid_obj.best_estimator_  

# Fit the best algorithm to the data. 
rnd.fit(x_train, Y_train)

yhat7=rnd.predict(x_test_)

(acc(Y_test,yhat7))*100
# Out:
# C:\Users\Akshat Singhal\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# 60.06276436075863

# %%
### VOTING CLASSIFIER(ENSEMBLE)

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.svm import SVC



voting_clf=VotingClassifier(estimators=[('lr',lr),('rf', rnd),('dt',tree),('knn',neigh),('rbf',clf3)], voting='soft')

voting_clf.fit(x_train,Y_train)

yhat6=voting_clf.predict(x_test_)

(acc(Y_test,yhat6))*100
# Out:
# 59.91267567198799

# %% [markdown]
# ### Note: As the maximum accuracy is achieved by using Random Forest model, hence using it to train the whole dataset and for final prediction.

# %%
### TRAINING ON FULL GIVEN DATASET

# WITH Random Forest:

rnd.fit(X_,y)


yhat_test=rnd.predict_proba(X_test_)

# %%
yhat_test=yhat_test[:,0]

# %%
df = pd.DataFrame(yhat_test)
df.columns=['is_goal']

# %%
df.shape
# Out:
# (6268, 1)

# %%
sub=pd.read_csv('sample_submission.csv')

# %%
sub['is_goal']=df['is_goal']

# %%
sub.to_csv('submission-13.csv')
